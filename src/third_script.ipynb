# %%
import os
import sys
import pandas as pd

from pyspark.sql import SparkSession
from pyspark import SparkContext
from pyspark.sql import SQLContext
from pyspark.sql import functions as F
from pyspark.sql.types import FloatType
from pyspark.sql.dataframe import DataFrame


@F.udf(returnType=FloatType())
def norm_gb_mb(col):
    import re

    col = str(col).lower().strip()
    gb_ind = "gb" in col
    mb_ind = "mb" in col
    col = re.sub(r"[a-zA-Zа-яА-Я]", "", col).replace(",", ".").strip()
    if "/" in col:
        value = col.split("/")[0]
    elif " " in col:
        value = col.split(" ")[0]
    else:
        value = col.strip()
    if gb_ind:
        return float(value)
    elif mb_ind:
        return float(value) / 1024
    else:
        return 0


def get_devices_dataset(spark: SparkSession, reporting_date: pd.Timestamp) -> DataFrame:
    dim_telinfo = spark.read.parquet("../data/dim_telinfo/*.parquet")
    telinfo_device_type = spark.read.csv(
        "../data/dim_device_type.csv", sep=";", header=True
    )
    cp = spark.read.parquet(
        "../data/customer_profile/"
        + "TIME_KEY={}".format(reporting_date.strftime("%Y-%m-%d"))
    )
    cnt_all = cp.count()
    cnt_active = cp.filter(
        F.col("DW_STATUS_KEY").isin(["A", "S"]) & (F.col("ACTIVE_IND") > 0)
    ).count()

    dim_telinfo = dim_telinfo.select(
        "TAC",
        "OS",
        "TOUCHSCREEN_IND",
        "CAMERA_IND",
        "CAMERA_RESOLUTION",
        "FIRST_DISP_TYPE",
        "FIRST_DISP_DIAG",
        "LAUNCH",
        "FUNCTIONALITY_CLASS",
        "WEIGHT",
        "TWO_SIM_IND",
        "RAM_CAPACITY",
        "ROM_CAPACITY",
        "MEMORY_CARD_IND",
        "BLUETOOTH_IND",
        "WLAN_IND",
        "GPS_IND",
        "GLONASS_IND",
        "A_GPS_IND",
        "GPRS_IND",
        "EDGE_IND",
        "LTE_IND",
        "IND_3G",
        "BRAND"
    )
    cp = cp.filter(F.col("PRIORITY_TAC").isNotNull())

    cp_agg = (
        cp.groupby("PRIORITY_TAC")
        .agg(
            F.count("*").alias("CNT_USERS_OVERALL"),
            F.sum(
                F.when(
                    F.col("DW_STATUS_KEY").isin(["A", "S"]) & (F.col("ACTIVE_IND") > 0),
                    1,
                ).otherwise(0)
            ).alias("CNT_ACTIVE_USERS"),
            F.sum("COUNT_DEVICE_CHANGES").alias("SUM_COUNT_DEVICE_CHANGES"),
            F.avg("COUNT_DEVICE_CHANGES").alias("AVG_COUNT_DEVICE_CHANGES"),
            F.avg("AVG_ARPU_3M").alias("AVG_ARPU_3M"),
            F.avg("COUNT_PERIODS_POSIT_REV_12M").alias(
                "AVG_COUNT_PERIODS_POSIT_REV_12M"
            ),
            F.avg("TOTAL_ROAM_MIN").alias("AVG_ROAM_MIN"),
            F.avg("CNT_CALL_OUT").alias("AVG_CNT_CALL_OUT"),
            F.avg("CNT_CALL_IN").alias("AVG_CNT_CALL_IN"),
            F.avg("VOICE_OUT_DURATION").alias("AVG_VOICE_OUT_DURATION"),
            F.avg("VOICE_IN_DURATION").alias("AVG_VOICE_IN_DURATION"),
            F.avg("UNIC_CTN_CPA").alias("AVG_UNIC_CTN_CPA"),
            F.avg("CNT_SMS_OUT").alias("AVG_CNT_SMS_OUT"),
            F.avg("CNT_SMS_IN").alias("AVG_CNT_SMS_IN"),
            F.avg("SMS_SHORT_NUM").alias("AVG_SMS_SHORT_NUM"),
            F.avg("TOTAL_DATA_VOLUME").alias("AVG_TOTAL_DATA_VOLUME"),
            F.avg("MIN_BALANCE").alias("AVG_MIN_BALANCE"),
            F.avg("AVG_BALANCE").alias("AVG_BALANCE"),
            F.avg("MAX_BALANCE").alias("AVG_MAX_BALANCE"),
            F.avg("STD_BALANCE").alias("AVG_STD_BALANCE"),
            F.avg("BLOCK_DAYS_COUNT").alias("AVG_BLOCK_DAYS_COUNT"),
        )
        .withColumn("PERC_USERS_OVERALL", F.col("CNT_USERS_OVERALL") / cnt_all)
        .withColumn("PERC_ACTIVE_USERS", F.col("CNT_ACTIVE_USERS") / cnt_active)
        .withColumn(
            "RATIO_ACTIVE_ALL", F.col("CNT_ACTIVE_USERS") / F.col("CNT_USERS_OVERALL")
        )
    )

    df = (
        cp_agg.withColumnRenamed("PRIORITY_TAC", "TAC")
        .join(telinfo_device_type, on=["TAC"], how="left")
        .join(dim_telinfo.filter("ROWNUMBER_CONTROL=1"), on=["TAC"], how="left")
    )
    df = (
        df.withColumn(
            "DEVICE_TYPE",
            F.when(
                F.trim(F.col("DEVICE_TYPE")).isin(
                    ["Feature_plus", "Smartphone", "Voice_centered", "Tablets"]
                ),
                F.trim(F.col("DEVICE_TYPE")),
            ).otherwise(F.lit("Others")),
        )
        .withColumn(
            "OS",
            F.when(
                F.trim(F.col("OS")).isin(
                    ["BlackBerry OS", "iOS", "Android", "Proprietary", "Symbian"]
                ),
                F.trim(F.col("OS")),
            ).otherwise(
                F.when(
                    F.trim(F.col("OS")).isin(
                        ["Windows Phone", "Windows Mobile", "Windows"]
                    ),
                    F.lit("Windows"),
                ).otherwise(F.lit("Others"))
            ),
        )
        .withColumn("TOUCHSCREEN_IND", F.col("TOUCHSCREEN_IND") == "Да")
        .withColumn("CAMERA_IND", F.col("CAMERA_IND") == "Да")
        .fillna(False, subset=["CAMERA_IND", "TOUCHSCREEN_IND"])
        .withColumn(
            "CAMERA_RESOLUTION",
            F.when(
                F.trim(F.col("CAMERA_RESOLUTION")).isin(["-99", "N/A", "Нет данных"])
                | F.col("CAMERA_RESOLUTION").isNull(),
                0,
            ).otherwise(
                F.regexp_replace(
                    F.split(F.trim(F.col("CAMERA_RESOLUTION")), " ").getItem(0),
                    ",",
                    ".",
                ).cast("float")
            ),
        )
        .withColumn(
            "FIRST_DISP_TYPE",
            F.when(
                F.trim(F.col("FIRST_DISP_TYPE")).isin(["-99", "N/A", "Нет данных"])
                | F.col("FIRST_DISP_TYPE").isNull(),
                F.lit("Nonname"),
            ).otherwise(
                F.when(
                    F.trim(F.col("FIRST_DISP_TYPE")).isin(
                        [
                            "Super AMOLED",
                            "AMOLED",
                            "Dynamic AMOLED",
                            "Super AMOLED Plus",
                            "Optic AMOLED",
                        ]
                    ),
                    F.lit("AMOLED"),
                ).otherwise(
                    F.when(
                        F.trim(F.col("FIRST_DISP_TYPE")).isin(
                            ["TFT", "PLS-TFT", "TFT IPS (SFT)", "PLS"]
                        ),
                        F.lit("TFT"),
                    ).otherwise(
                        F.when(
                            F.trim(F.col("FIRST_DISP_TYPE")).isin(
                                ["IPS", "Super IPS+", "True HD IPS Plus"]
                            ),
                            F.lit("IPS"),
                        ).otherwise(
                            F.when(
                                F.trim(F.col("FIRST_DISP_TYPE")).isin(
                                    [
                                        "LCD",
                                        "UFB-LCD",
                                        "Super LCD",
                                        "Super LCD 5",
                                        "Super LCD 6",
                                        "3D LCD",
                                    ]
                                ),
                                F.lit("LCD"),
                            ).otherwise(
                                F.when(
                                    F.trim(F.col("FIRST_DISP_TYPE")).isin(
                                        ["CSTN", "STN"]
                                    ),
                                    F.lit("STN"),
                                ).otherwise(
                                    F.when(
                                        F.trim(F.col("FIRST_DISP_TYPE")).isin(
                                            ["OLED", "TN", "LTPS"]
                                        ),
                                        F.trim(F.col("FIRST_DISP_TYPE")),
                                    ).otherwise(F.lit("Others"))
                                )
                            )
                        )
                    )
                )
            ),
        )
        .withColumn(
            "FIRST_DISP_DIAG",
            F.when(
                F.trim(F.col("FIRST_DISP_DIAG")).isin(["-99", "N/A", "Нет данных"])
                | F.col("FIRST_DISP_DIAG").isNull(),
                0,
            ).otherwise(
                F.regexp_replace(
                    F.split(F.trim(F.col("FIRST_DISP_DIAG")), " ").getItem(0), ",", "."
                ).cast("float")
            ),
        )
        .withColumn(
            "LT_DEVICE",
            F.when(
                F.length(F.col("LAUNCH")) == 10,
                F.datediff(
                    F.lit(reporting_date.strftime("%Y-%m-%d")),
                    F.col("LAUNCH").cast("date"),
                ),
            ).otherwise(None),
        )
        .withColumn(
            "FUNCTIONALITY_CLASS",
            F.when(
                F.trim(F.col("FUNCTIONALITY_CLASS")).isin(["-99", "N/A"])
                | F.col("FUNCTIONALITY_CLASS").isNull(),
                "Unknown",
            ).otherwise(F.trim(F.col("FUNCTIONALITY_CLASS"))),
        )
        .withColumn(
            "WEIGHT",
            F.when(
                F.trim(F.col("WEIGHT")).isin(["-99", "N/A", "Нет данных"])
                | F.col("WEIGHT").isNull(),
                0,
            ).otherwise(F.trim(F.col("WEIGHT")).cast("float")),
        )
        .withColumn(
            "MULTISIM_IND",
            F.when(
                F.trim(F.col("TWO_SIM_IND")).isin(
                    [
                        "2 UICC",
                        "3 UICC",
                        "4 UICC",
                        "2 SIM-карты",
                        "Да",
                        "В зависимости от оконечного устройства",
                    ]
                ),
                True,
            ).otherwise(False),
        )
        .withColumn(
            "RAM_CAPACITY",
            F.when(
                F.trim(F.col("RAM_CAPACITY")).isin(["-99", "N/A", "Нет данных"])
                | F.col("RAM_CAPACITY").isNull(),
                0,
            ).otherwise(norm_gb_mb(F.col("RAM_CAPACITY"))),
        )
        .withColumn(
            "ROM_CAPACITY",
            F.when(
                F.trim(F.col("ROM_CAPACITY")).isin(["-99", "N/A", "Нет данных"])
                | F.col("ROM_CAPACITY").isNull(),
                0,
            ).otherwise(norm_gb_mb(F.col("ROM_CAPACITY"))),
        )
        .withColumn(
            "MEMORY_CARD_IND",
            F.when(F.trim(F.col("MEMORY_CARD_IND")).isin(["Да"]), True).otherwise(
                False
            ),
        )
        .withColumn(
            "BLUETOOTH_IND",
            F.when(F.trim(F.col("BLUETOOTH_IND")).isin(["Да"]), True).otherwise(False),
        )
        .withColumn(
            "WLAN_IND",
            F.when(F.trim(F.col("WLAN_IND")).isin(["Да"]), True).otherwise(False),
        )
        .withColumn(
            "GPS_IND",
            F.when(F.trim(F.col("GPS_IND")).isin(["Да"]), True).otherwise(False),
        )
        .withColumn(
            "GLONASS_IND",
            F.when(F.trim(F.col("GLONASS_IND")).isin(["Да"]), True).otherwise(False),
        )
        .withColumn(
            "A_GPS_IND",
            F.when(F.trim(F.col("A_GPS_IND")).isin(["Да"]), True).otherwise(False),
        )
        .withColumn(
            "GPRS_IND",
            F.when(F.trim(F.col("GPRS_IND")).isin(["Да"]), True).otherwise(False),
        )
        .withColumn(
            "EDGE_IND",
            F.when(F.trim(F.col("EDGE_IND")).isin(["Да"]), True).otherwise(False),
        )
        .withColumn(
            "LTE_IND",
            F.when(F.trim(F.col("LTE_IND")).isin(["Да"]), True).otherwise(False),
        )
        .withColumn(
            "IND_3G",
            F.when(F.trim(F.col("IND_3G")).isin(["Да"]), True).otherwise(False),
        )
        .withColumn("IS_NOKIA", F.col("BRAND") == "Nokia")
        .withColumn("IS_SAMSUNG", F.col("BRAND") == "Samsung")
        .withColumn("IS_APPLE", F.col("BRAND") == "Apple")
        .withColumn("IS_XIAOMI", F.col("BRAND") == "Xiaomi")
        .withColumn(
            "IS_HUAWEI", F.col("BRAND").isin(["Huawei", "Huawei Honor", "Honor"])
        )
        .withColumn("IS_GOOGLE", F.col("BRAND") == "Google")
        .withColumn("IS_MEIZU", F.col("BRAND") == "Meizu")
        .withColumn("IS_EXPENSIVE", F.col("BRAND").isin(["BlackBerry", "Vertu"]))
    )

    avito_min_date = pd.to_datetime("2019-12-01")
    avito_date_1m = (
        avito_min_date if reporting_date < avito_min_date else reporting_date
    )
    avito_date_2m = avito_date_1m + pd.DateOffset(months=-1)
    avito_date_3m = avito_date_1m + pd.DateOffset(months=-2)

    avito_date_2m = avito_date_2m if avito_date_2m > avito_min_date else avito_min_date
    avito_date_3m = avito_date_3m if avito_date_3m > avito_min_date else avito_min_date

    avito_phones_hdfs = "../data/datamart_avito_phones/"
    avito_phones_1m = spark.read.parquet(
        avito_phones_hdfs + "MONTH_KEY={}".format(avito_date_1m.strftime("%Y-%m-%d"))
    )
    avito_phones_2m = spark.read.parquet(
        avito_phones_hdfs + "MONTH_KEY={}".format(avito_date_2m.strftime("%Y-%m-%d"))
    )
    avito_phones_3m = spark.read.parquet(
        avito_phones_hdfs + "MONTH_KEY={}".format(avito_date_3m.strftime("%Y-%m-%d"))
    )

    avito_phones_1m.createOrReplaceTempView("avito_phones_1m")
    avito_phones_2m.createOrReplaceTempView("avito_phones_2m")
    avito_phones_3m.createOrReplaceTempView("avito_phones_3m")

    avito_phones_1m = spark.sql(
        """
        SELECT 
            TAC,
            CASE WHEN price_rub_to_kzt IS NULL THEN price WHEN price IS NULL THEN price_rub_to_kzt ELSE (price_rub_to_kzt + price) / 2 END avg_avito_price_1m
        FROM avito_phones_1m
    """
    )
    avito_phones_2m = spark.sql(
        """
        SELECT 
            TAC,
            CASE WHEN price_rub_to_kzt IS NULL THEN price WHEN price IS NULL THEN price_rub_to_kzt ELSE (price_rub_to_kzt + price) / 2 END avg_avito_price_2m
        FROM avito_phones_2m
    """
    )
    avito_phones_3m = spark.sql(
        """
        SELECT 
            TAC,
            CASE WHEN price_rub_to_kzt IS NULL THEN price WHEN price IS NULL THEN price_rub_to_kzt ELSE (price_rub_to_kzt + price) / 2 END avg_avito_price_3m
        FROM avito_phones_3m
    """
    )
    df = (
        df.join(avito_phones_1m, on=["TAC"], how="left")
        .join(avito_phones_2m, on=["TAC"], how="left")
        .join(avito_phones_3m, on=["TAC"], how="left")
        .withColumn(
            "NOT_NULL_PRICE_AMT_AVITO",
            sum(
                [
                    F.col("avg_avito_price_1m").isNotNull().cast("integer"),
                    F.col("avg_avito_price_2m").isNotNull().cast("integer"),
                    F.col("avg_avito_price_3m").isNotNull().cast("integer"),
                ]
            ),
        )
        .withColumn(
            "AVG_PRICE_3M_AVITO",
            sum(
                [
                    F.col("avg_avito_price_1m"),
                    F.col("avg_avito_price_1m"),
                    F.col("avg_avito_price_1m"),
                ]
            )
            / F.col("NOT_NULL_PRICE_AMT_AVITO"),
        )
    )

    telprice_old = spark.read.csv(
        "../data/vendor_telprice.csv", sep=";", header=True
    )
    df = (
        df.join(
            telprice_old.select(
                F.col("PRIORITY_TAC").alias("TAC"),
                F.col("PRICE").alias("PRICE_VENDOR_OLD").cast("float"),
            ),
            on="TAC",
            how="left",
        )
        .withColumn(
            "AVG_PRICE",
            F.when(
                F.col("avg_avito_price_1m").isNotNull()
                & F.col("PRICE_VENDOR_OLD").isNotNull(),
                (F.col("avg_avito_price_1m") + F.col("PRICE_VENDOR_OLD")) / 2,
            )
            .otherwise(
                F.when(
                    F.col("avg_avito_price_1m").isNotNull(), F.col("avg_avito_price_1m")
                ).otherwise(F.col("PRICE_VENDOR_OLD"))
            )
            .cast("float"),
        )
        .withColumn(
            "AVG_PRICE_3M",
            F.when(
                F.col("AVG_PRICE_3M_AVITO").isNotNull()
                & F.col("PRICE_VENDOR_OLD").isNotNull(),
                (F.col("AVG_PRICE_3M_AVITO") + F.col("PRICE_VENDOR_OLD")) / 2,
            )
            .otherwise(
                F.when(
                    F.col("AVG_PRICE_3M_AVITO").isNotNull(), F.col("AVG_PRICE_3M_AVITO")
                ).otherwise(F.col("PRICE_VENDOR_OLD"))
            )
            .cast("float"),
        )
        .withColumn(
            "TARGET_PRICE",
            F.when(
                F.col("avg_avito_price_1m").isNotNull(), F.col("avg_avito_price_1m")
            ).otherwise(F.col("PRICE_VENDOR_OLD")),
        )
    )
    df = (
        df.withColumn("avg_avito_price_1m", F.col("avg_avito_price_1m").cast("float"))
        .withColumn("avg_avito_price_2m", F.col("avg_avito_price_2m").cast("float"))
        .withColumn("avg_avito_price_3m", F.col("avg_avito_price_3m").cast("float"))
        .withColumn("TARGET_PRICE", F.col("TARGET_PRICE").cast("float"))
    )
    return df.drop("TWO_SIM_IND", "LAUNCH").withColumn(
        "MONTH_KEY", F.lit(reporting_date.strftime("%Y-%m-%d")).cast("date")
    )


def test_cases(spark_df):
    return 0

# %%
from datetime import datetime
argdate = datetime(2018, 11, 1)

# %%
sc = SparkContext.getOrCreate()
spark = SQLContext(sc)
# Out:
# /home/dulat/.local/lib/python3.8/site-packages/pyspark/sql/context.py:112: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(

# %%
dataset = get_devices_dataset(spark, argdate)
assert 0 == test_cases(dataset)

# %%
dataset.explain('formatted')
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (45)
# +- Project (44)
#    +- BroadcastHashJoin LeftOuter BuildRight (43)
#       :- Project (38)
#       :  +- Project (37)
#       :     +- BroadcastHashJoin LeftOuter BuildRight (36)
#       :        :- Project (31)
#       :        :  +- BroadcastHashJoin LeftOuter BuildRight (30)
#       :        :     :- Project (25)
#       :        :     :  +- BroadcastHashJoin LeftOuter BuildRight (24)
#       :        :     :     :- Project (19)
#       :        :     :     :  +- BatchEvalPython (18)
#       :        :     :     :     +- Project (17)
#       :        :     :     :        +- BroadcastHashJoin LeftOuter BuildRight (16)
#       :        :     :     :           :- Project (11)
#       :        :     :     :           :  +- BroadcastHashJoin LeftOuter BuildRight (10)
#       :        :     :     :           :     :- Project (6)
#       :        :     :     :           :     :  +- HashAggregate (5)
#       :        :     :     :           :     :     +- Exchange (4)
#       :        :     :     :           :     :        +- HashAggregate (3)
#       :        :     :     :           :     :           +- Filter (2)
#       :        :     :     :           :     :              +- Scan parquet  (1)
#       :        :     :     :           :     +- BroadcastExchange (9)
#       :        :     :     :           :        +- Filter (8)
#       :        :     :     :           :           +- Scan csv  (7)
#       :        :     :     :           +- BroadcastExchange (15)
#       :        :     :     :              +- Project (14)
#       :        :     :     :                 +- Filter (13)
#       :        :     :     :                    +- Scan parquet  (12)
#       :        :     :     +- BroadcastExchange (23)
#       :        :     :        +- Project (22)
#       :        :     :           +- Filter (21)
#       :        :     :              +- Scan parquet  (20)
#       :        :     +- BroadcastExchange (29)
#       :        :        +- Project (28)
#       :        :           +- Filter (27)
#       :        :              +- Scan parquet  (26)
#       :        +- BroadcastExchange (35)
#       :           +- Project (34)
#       :              +- Filter (33)
#       :                 +- Scan parquet  (32)
#       +- BroadcastExchange (42)
#          +- Project (41)
#             +- Filter (40)
#                +- Scan csv  (39)
#
#
# (1) Scan parquet
# Output [21]: [PRIORITY_TAC#7481, ACTIVE_IND#7482, DW_STATUS_KEY#7483, COUNT_DEVICE_CHANGES#7484L, AVG_ARPU_3M#7486, COUNT_PERIODS_POSIT_REV_12M#7487L, TOTAL_ROAM_MIN#7488, CNT_CALL_OUT#7489, CNT_CALL_IN#7490, VOICE_OUT_DURATION#7491, VOICE_IN_DURATION#7492, UNIC_CTN_CPA#7493, CNT_SMS_OUT#7494, CNT_SMS_IN#7495, SMS_SHORT_NUM#7496, TOTAL_DATA_VOLUME#7498, MIN_BALANCE#7499, AVG_BALANCE#7500, MAX_BALANCE#7501, STD_BALANCE#7502, BLOCK_DAYS_COUNT#7503L]
# Batched: true
# Location: InMemoryFileIndex [file:/home/dulat/Desktop/nu-hackathon/data/customer_profile/TIME_KEY=2018-11-01]
# PushedFilters: [IsNotNull(PRIORITY_TAC)]
# ReadSchema: struct<PRIORITY_TAC:int,ACTIVE_IND:int,DW_STATUS_KEY:string,COUNT_DEVICE_CHANGES:bigint,AVG_ARPU_3M:double,COUNT_PERIODS_POSIT_REV_12M:bigint,TOTAL_ROAM_MIN:decimal(18,2),CNT_CALL_OUT:decimal(18,2),CNT_CALL_IN:decimal(18,2),VOICE_OUT_DURATION:decimal(18,2),VOICE_IN_DURATION:decimal(18,2),UNIC_CTN_CPA:decimal(18,2),CNT_SMS_OUT:decimal(18,2),CNT_SMS_IN:decimal(18,2),SMS_SHORT_NUM:decimal(18,2),TOTAL_DATA_VOLUME:decimal(18,2),MIN_BALANCE:decimal(38,2),AVG_BALANCE:decimal(38,6),MAX_BALANCE:decimal(38,2),STD_BALANCE:double,BLOCK_DAYS_COUNT:bigint>
#
# (2) Filter
# Input [21]: [PRIORITY_TAC#7481, ACTIVE_IND#7482, DW_STATUS_KEY#7483, COUNT_DEVICE_CHANGES#7484L, AVG_ARPU_3M#7486, COUNT_PERIODS_POSIT_REV_12M#7487L, TOTAL_ROAM_MIN#7488, CNT_CALL_OUT#7489, CNT_CALL_IN#7490, VOICE_OUT_DURATION#7491, VOICE_IN_DURATION#7492, UNIC_CTN_CPA#7493, CNT_SMS_OUT#7494, CNT_SMS_IN#7495, SMS_SHORT_NUM#7496, TOTAL_DATA_VOLUME#7498, MIN_BALANCE#7499, AVG_BALANCE#7500, MAX_BALANCE#7501, STD_BALANCE#7502, BLOCK_DAYS_COUNT#7503L]
# Condition : isnotnull(PRIORITY_TAC#7481)
#
# (3) HashAggregate
# Input [21]: [PRIORITY_TAC#7481, ACTIVE_IND#7482, DW_STATUS_KEY#7483, COUNT_DEVICE_CHANGES#7484L, AVG_ARPU_3M#7486, COUNT_PERIODS_POSIT_REV_12M#7487L, TOTAL_ROAM_MIN#7488, CNT_CALL_OUT#7489, CNT_CALL_IN#7490, VOICE_OUT_DURATION#7491, VOICE_IN_DURATION#7492, UNIC_CTN_CPA#7493, CNT_SMS_OUT#7494, CNT_SMS_IN#7495, SMS_SHORT_NUM#7496, TOTAL_DATA_VOLUME#7498, MIN_BALANCE#7499, AVG_BALANCE#7500, MAX_BALANCE#7501, STD_BALANCE#7502, BLOCK_DAYS_COUNT#7503L]
# Keys [1]: [PRIORITY_TAC#7481]
# Functions [21]: [partial_count(1), partial_sum(CASE WHEN (DW_STATUS_KEY#7483 IN (A,S) AND (ACTIVE_IND#7482 > 0)) THEN 1 ELSE 0 END), partial_sum(COUNT_DEVICE_CHANGES#7484L), partial_avg(COUNT_DEVICE_CHANGES#7484L), partial_avg(AVG_ARPU_3M#7486), partial_avg(COUNT_PERIODS_POSIT_REV_12M#7487L), partial_avg(TOTAL_ROAM_MIN#7488), partial_avg(CNT_CALL_OUT#7489), partial_avg(CNT_CALL_IN#7490), partial_avg(VOICE_OUT_DURATION#7491), partial_avg(VOICE_IN_DURATION#7492), partial_avg(UNIC_CTN_CPA#7493), partial_avg(CNT_SMS_OUT#7494), partial_avg(CNT_SMS_IN#7495), partial_avg(SMS_SHORT_NUM#7496), partial_avg(TOTAL_DATA_VOLUME#7498), partial_avg(MIN_BALANCE#7499), partial_avg(AVG_BALANCE#7500), partial_avg(MAX_BALANCE#7501), partial_avg(STD_BALANCE#7502), partial_avg(BLOCK_DAYS_COUNT#7503L)]
# Aggregate Attributes [39]: [count#10671L, sum#10672L, sum#10673L, sum#10674, count#10675L, sum#10676, count#10677L, sum#10678, count#10679L, sum#10680, count#10681L, sum#10682, count#10683L, sum#10684, count#10685L, sum#10686, count#10687L, sum#10688, count#10689L, sum#10690, count#10691L, sum#10692, count#10693L, sum#10694, count#10695L, sum#10696, count#10697L, sum#10698, count#10699L, sum#10700, count#10701L, sum#10702, count#10703L, sum#10704, count#10705L, sum#10706, count#10707L, sum#10708, count#10709L]
# Results [40]: [PRIORITY_TAC#7481, count#10710L, sum#10711L, sum#10712L, sum#10713, count#10714L, sum#10715, count#10716L, sum#10717, count#10718L, sum#10719, count#10720L, sum#10721, count#10722L, sum#10723, count#10724L, sum#10725, count#10726L, sum#10727, count#10728L, sum#10729, count#10730L, sum#10731, count#10732L, sum#10733, count#10734L, sum#10735, count#10736L, sum#10737, count#10738L, sum#10739, count#10740L, sum#10741, count#10742L, sum#10743, count#10744L, sum#10745, count#10746L, sum#10747, count#10748L]
#
# (4) Exchange
# Input [40]: [PRIORITY_TAC#7481, count#10710L, sum#10711L, sum#10712L, sum#10713, count#10714L, sum#10715, count#10716L, sum#10717, count#10718L, sum#10719, count#10720L, sum#10721, count#10722L, sum#10723, count#10724L, sum#10725, count#10726L, sum#10727, count#10728L, sum#10729, count#10730L, sum#10731, count#10732L, sum#10733, count#10734L, sum#10735, count#10736L, sum#10737, count#10738L, sum#10739, count#10740L, sum#10741, count#10742L, sum#10743, count#10744L, sum#10745, count#10746L, sum#10747, count#10748L]
# Arguments: hashpartitioning(PRIORITY_TAC#7481, 200), ENSURE_REQUIREMENTS, [id=#894]
#
# (5) HashAggregate
# Input [40]: [PRIORITY_TAC#7481, count#10710L, sum#10711L, sum#10712L, sum#10713, count#10714L, sum#10715, count#10716L, sum#10717, count#10718L, sum#10719, count#10720L, sum#10721, count#10722L, sum#10723, count#10724L, sum#10725, count#10726L, sum#10727, count#10728L, sum#10729, count#10730L, sum#10731, count#10732L, sum#10733, count#10734L, sum#10735, count#10736L, sum#10737, count#10738L, sum#10739, count#10740L, sum#10741, count#10742L, sum#10743, count#10744L, sum#10745, count#10746L, sum#10747, count#10748L]
# Keys [1]: [PRIORITY_TAC#7481]
# Functions [21]: [count(1), sum(CASE WHEN (DW_STATUS_KEY#7483 IN (A,S) AND (ACTIVE_IND#7482 > 0)) THEN 1 ELSE 0 END), sum(COUNT_DEVICE_CHANGES#7484L), avg(COUNT_DEVICE_CHANGES#7484L), avg(AVG_ARPU_3M#7486), avg(COUNT_PERIODS_POSIT_REV_12M#7487L), avg(TOTAL_ROAM_MIN#7488), avg(CNT_CALL_OUT#7489), avg(CNT_CALL_IN#7490), avg(VOICE_OUT_DURATION#7491), avg(VOICE_IN_DURATION#7492), avg(UNIC_CTN_CPA#7493), avg(CNT_SMS_OUT#7494), avg(CNT_SMS_IN#7495), avg(SMS_SHORT_NUM#7496), avg(TOTAL_DATA_VOLUME#7498), avg(MIN_BALANCE#7499), avg(AVG_BALANCE#7500), avg(MAX_BALANCE#7501), avg(STD_BALANCE#7502), avg(BLOCK_DAYS_COUNT#7503L)]
# Aggregate Attributes [21]: [count(1)#7642L, sum(CASE WHEN (DW_STATUS_KEY#7483 IN (A,S) AND (ACTIVE_IND#7482 > 0)) THEN 1 ELSE 0 END)#7644L, sum(COUNT_DEVICE_CHANGES#7484L)#7646L, avg(COUNT_DEVICE_CHANGES#7484L)#7648, avg(AVG_ARPU_3M#7486)#7650, avg(COUNT_PERIODS_POSIT_REV_12M#7487L)#7652, avg(TOTAL_ROAM_MIN#7488)#7654, avg(CNT_CALL_OUT#7489)#7656, avg(CNT_CALL_IN#7490)#7658, avg(VOICE_OUT_DURATION#7491)#7660, avg(VOICE_IN_DURATION#7492)#7662, avg(UNIC_CTN_CPA#7493)#7664, avg(CNT_SMS_OUT#7494)#7666, avg(CNT_SMS_IN#7495)#7668, avg(SMS_SHORT_NUM#7496)#7670, avg(TOTAL_DATA_VOLUME#7498)#7672, avg(MIN_BALANCE#7499)#7674, avg(AVG_BALANCE#7500)#7676, avg(MAX_BALANCE#7501)#7678, avg(STD_BALANCE#7502)#7680, avg(BLOCK_DAYS_COUNT#7503L)#7682]
# Results [22]: [PRIORITY_TAC#7481, count(1)#7642L AS CNT_USERS_OVERALL#7643L, sum(CASE WHEN (DW_STATUS_KEY#7483 IN (A,S) AND (ACTIVE_IND#7482 > 0)) THEN 1 ELSE 0 END)#7644L AS CNT_ACTIVE_USERS#7645L, sum(COUNT_DEVICE_CHANGES#7484L)#7646L AS SUM_COUNT_DEVICE_CHANGES#7647L, avg(COUNT_DEVICE_CHANGES#7484L)#7648 AS AVG_COUNT_DEVICE_CHANGES#7649, avg(AVG_ARPU_3M#7486)#7650 AS AVG_ARPU_3M#7651, avg(COUNT_PERIODS_POSIT_REV_12M#7487L)#7652 AS AVG_COUNT_PERIODS_POSIT_REV_12M#7653, avg(TOTAL_ROAM_MIN#7488)#7654 AS AVG_ROAM_MIN#7655, avg(CNT_CALL_OUT#7489)#7656 AS AVG_CNT_CALL_OUT#7657, avg(CNT_CALL_IN#7490)#7658 AS AVG_CNT_CALL_IN#7659, avg(VOICE_OUT_DURATION#7491)#7660 AS AVG_VOICE_OUT_DURATION#7661, avg(VOICE_IN_DURATION#7492)#7662 AS AVG_VOICE_IN_DURATION#7663, avg(UNIC_CTN_CPA#7493)#7664 AS AVG_UNIC_CTN_CPA#7665, avg(CNT_SMS_OUT#7494)#7666 AS AVG_CNT_SMS_OUT#7667, avg(CNT_SMS_IN#7495)#7668 AS AVG_CNT_SMS_IN#7669, avg(SMS_SHORT_NUM#7496)#7670 AS AVG_SMS_SHORT_NUM#7671, avg(TOTAL_DATA_VOLUME#7498)#7672 AS AVG_TOTAL_DATA_VOLUME#7673, avg(MIN_BALANCE#7499)#7674 AS AVG_MIN_BALANCE#7675, avg(AVG_BALANCE#7500)#7676 AS AVG_BALANCE#7677, avg(MAX_BALANCE#7501)#7678 AS AVG_MAX_BALANCE#7679, avg(STD_BALANCE#7502)#7680 AS AVG_STD_BALANCE#7681, avg(BLOCK_DAYS_COUNT#7503L)#7682 AS AVG_BLOCK_DAYS_COUNT#7683]
#
# (6) Project
# Output [25]: [PRIORITY_TAC#7481 AS TAC#7781, CNT_USERS_OVERALL#7643L, CNT_ACTIVE_USERS#7645L, SUM_COUNT_DEVICE_CHANGES#7647L, AVG_COUNT_DEVICE_CHANGES#7649, AVG_ARPU_3M#7651, AVG_COUNT_PERIODS_POSIT_REV_12M#7653, AVG_ROAM_MIN#7655, AVG_CNT_CALL_OUT#7657, AVG_CNT_CALL_IN#7659, AVG_VOICE_OUT_DURATION#7661, AVG_VOICE_IN_DURATION#7663, AVG_UNIC_CTN_CPA#7665, AVG_CNT_SMS_OUT#7667, AVG_CNT_SMS_IN#7669, AVG_SMS_SHORT_NUM#7671, AVG_TOTAL_DATA_VOLUME#7673, AVG_MIN_BALANCE#7675, AVG_BALANCE#7677, AVG_MAX_BALANCE#7679, AVG_STD_BALANCE#7681, AVG_BLOCK_DAYS_COUNT#7683, (cast(CNT_USERS_OVERALL#7643L as double) / 72922.0) AS PERC_USERS_OVERALL#7706, (cast(CNT_ACTIVE_USERS#7645L as double) / 36254.0) AS PERC_ACTIVE_USERS#7730, (cast(CNT_ACTIVE_USERS#7645L as double) / cast(CNT_USERS_OVERALL#7643L as double)) AS RATIO_ACTIVE_ALL#7755]
# Input [22]: [PRIORITY_TAC#7481, CNT_USERS_OVERALL#7643L, CNT_ACTIVE_USERS#7645L, SUM_COUNT_DEVICE_CHANGES#7647L, AVG_COUNT_DEVICE_CHANGES#7649, AVG_ARPU_3M#7651, AVG_COUNT_PERIODS_POSIT_REV_12M#7653, AVG_ROAM_MIN#7655, AVG_CNT_CALL_OUT#7657, AVG_CNT_CALL_IN#7659, AVG_VOICE_OUT_DURATION#7661, AVG_VOICE_IN_DURATION#7663, AVG_UNIC_CTN_CPA#7665, AVG_CNT_SMS_OUT#7667, AVG_CNT_SMS_IN#7669, AVG_SMS_SHORT_NUM#7671, AVG_TOTAL_DATA_VOLUME#7673, AVG_MIN_BALANCE#7675, AVG_BALANCE#7677, AVG_MAX_BALANCE#7679, AVG_STD_BALANCE#7681, AVG_BLOCK_DAYS_COUNT#7683]
#
# (7) Scan csv
# Output [2]: [TAC#7477, DEVICE_TYPE#7478]
# Batched: false
# Location: InMemoryFileIndex [file:/home/dulat/Desktop/nu-hackathon/data/dim_device_type.csv]
# PushedFilters: [IsNotNull(TAC)]
# ReadSchema: struct<TAC:string,DEVICE_TYPE:string>
#
# (8) Filter
# Input [2]: [TAC#7477, DEVICE_TYPE#7478]
# Condition : isnotnull(TAC#7477)
#
# (9) BroadcastExchange
# Input [2]: [TAC#7477, DEVICE_TYPE#7478]
# Arguments: HashedRelationBroadcastMode(List(cast(cast(input[0, string, false] as int) as bigint)),false), [id=#898]
#
# (10) BroadcastHashJoin
# Left keys [1]: [TAC#7781]
# Right keys [1]: [cast(TAC#7477 as int)]
# Join condition: None
#
# (11) Project
# Output [26]: [TAC#7781, CNT_USERS_OVERALL#7643L, CNT_ACTIVE_USERS#7645L, SUM_COUNT_DEVICE_CHANGES#7647L, AVG_COUNT_DEVICE_CHANGES#7649, AVG_ARPU_3M#7651, AVG_COUNT_PERIODS_POSIT_REV_12M#7653, AVG_ROAM_MIN#7655, AVG_CNT_CALL_OUT#7657, AVG_CNT_CALL_IN#7659, AVG_VOICE_OUT_DURATION#7661, AVG_VOICE_IN_DURATION#7663, AVG_UNIC_CTN_CPA#7665, AVG_CNT_SMS_OUT#7667, AVG_CNT_SMS_IN#7669, AVG_SMS_SHORT_NUM#7671, AVG_TOTAL_DATA_VOLUME#7673, AVG_MIN_BALANCE#7675, AVG_BALANCE#7677, AVG_MAX_BALANCE#7679, AVG_STD_BALANCE#7681, AVG_BLOCK_DAYS_COUNT#7683, PERC_USERS_OVERALL#7706, PERC_ACTIVE_USERS#7730, RATIO_ACTIVE_ALL#7755, DEVICE_TYPE#7478]
# Input [27]: [TAC#7781, CNT_USERS_OVERALL#7643L, CNT_ACTIVE_USERS#7645L, SUM_COUNT_DEVICE_CHANGES#7647L, AVG_COUNT_DEVICE_CHANGES#7649, AVG_ARPU_3M#7651, AVG_COUNT_PERIODS_POSIT_REV_12M#7653, AVG_ROAM_MIN#7655, AVG_CNT_CALL_OUT#7657, AVG_CNT_CALL_IN#7659, AVG_VOICE_OUT_DURATION#7661, AVG_VOICE_IN_DURATION#7663, AVG_UNIC_CTN_CPA#7665, AVG_CNT_SMS_OUT#7667, AVG_CNT_SMS_IN#7669, AVG_SMS_SHORT_NUM#7671, AVG_TOTAL_DATA_VOLUME#7673, AVG_MIN_BALANCE#7675, AVG_BALANCE#7677, AVG_MAX_BALANCE#7679, AVG_STD_BALANCE#7681, AVG_BLOCK_DAYS_COUNT#7683, PERC_USERS_OVERALL#7706, PERC_ACTIVE_USERS#7730, RATIO_ACTIVE_ALL#7755, TAC#7477, DEVICE_TYPE#7478]
#
# (12) Scan parquet
# Output [25]: [TAC#7166, OS#7169, IND_3G#7171, TOUCHSCREEN_IND#7172, CAMERA_IND#7177, CAMERA_RESOLUTION#7178, FIRST_DISP_TYPE#7192, FIRST_DISP_DIAG#7195, LAUNCH#7197, FUNCTIONALITY_CLASS#7199, WEIGHT#7201, TWO_SIM_IND#7209, RAM_CAPACITY#7236, ROM_CAPACITY#7237, MEMORY_CARD_IND#7238, BLUETOOTH_IND#7244, WLAN_IND#7246, GPS_IND#7248, GLONASS_IND#7249, A_GPS_IND#7250, GPRS_IND#7278, EDGE_IND#7280, LTE_IND#7307, ROWNUMBER_CONTROL#7311, BRAND#7312]
# Batched: true
# Location: InMemoryFileIndex [file:/home/dulat/Desktop/nu-hackathon/data/dim_telinfo/part-00000-282632e1-88bd-4b32-a92e-6bad7d3ae770-c000.snappy.parquet]
# PushedFilters: [IsNotNull(ROWNUMBER_CONTROL), IsNotNull(TAC)]
# ReadSchema: struct<TAC:int,OS:string,IND_3G:string,TOUCHSCREEN_IND:string,CAMERA_IND:string,CAMERA_RESOLUTION:string,FIRST_DISP_TYPE:string,FIRST_DISP_DIAG:string,LAUNCH:string,FUNCTIONALITY_CLASS:string,WEIGHT:string,TWO_SIM_IND:string,RAM_CAPACITY:string,ROM_CAPACITY:string,MEMORY_CARD_IND:string,BLUETOOTH_IND:string,WLAN_IND:string,GPS_IND:string,GLONASS_IND:string,A_GPS_IND:string,GPRS_IND:string,EDGE_IND:string,LTE_IND:string,ROWNUMBER_CONTROL:string,BRAND:string>
#
# (13) Filter
# Input [25]: [TAC#7166, OS#7169, IND_3G#7171, TOUCHSCREEN_IND#7172, CAMERA_IND#7177, CAMERA_RESOLUTION#7178, FIRST_DISP_TYPE#7192, FIRST_DISP_DIAG#7195, LAUNCH#7197, FUNCTIONALITY_CLASS#7199, WEIGHT#7201, TWO_SIM_IND#7209, RAM_CAPACITY#7236, ROM_CAPACITY#7237, MEMORY_CARD_IND#7238, BLUETOOTH_IND#7244, WLAN_IND#7246, GPS_IND#7248, GLONASS_IND#7249, A_GPS_IND#7250, GPRS_IND#7278, EDGE_IND#7280, LTE_IND#7307, ROWNUMBER_CONTROL#7311, BRAND#7312]
# Condition : ((isnotnull(ROWNUMBER_CONTROL#7311) AND (cast(ROWNUMBER_CONTROL#7311 as int) = 1)) AND isnotnull(TAC#7166))
#
# (14) Project
# Output [24]: [TAC#7166, OS#7169, TOUCHSCREEN_IND#7172, CAMERA_IND#7177, CAMERA_RESOLUTION#7178, FIRST_DISP_TYPE#7192, FIRST_DISP_DIAG#7195, LAUNCH#7197, FUNCTIONALITY_CLASS#7199, WEIGHT#7201, TWO_SIM_IND#7209, RAM_CAPACITY#7236, ROM_CAPACITY#7237, MEMORY_CARD_IND#7238, BLUETOOTH_IND#7244, WLAN_IND#7246, GPS_IND#7248, GLONASS_IND#7249, A_GPS_IND#7250, GPRS_IND#7278, EDGE_IND#7280, LTE_IND#7307, IND_3G#7171, BRAND#7312]
# Input [25]: [TAC#7166, OS#7169, IND_3G#7171, TOUCHSCREEN_IND#7172, CAMERA_IND#7177, CAMERA_RESOLUTION#7178, FIRST_DISP_TYPE#7192, FIRST_DISP_DIAG#7195, LAUNCH#7197, FUNCTIONALITY_CLASS#7199, WEIGHT#7201, TWO_SIM_IND#7209, RAM_CAPACITY#7236, ROM_CAPACITY#7237, MEMORY_CARD_IND#7238, BLUETOOTH_IND#7244, WLAN_IND#7246, GPS_IND#7248, GLONASS_IND#7249, A_GPS_IND#7250, GPRS_IND#7278, EDGE_IND#7280, LTE_IND#7307, ROWNUMBER_CONTROL#7311, BRAND#7312]
#
# (15) BroadcastExchange
# Input [24]: [TAC#7166, OS#7169, TOUCHSCREEN_IND#7172, CAMERA_IND#7177, CAMERA_RESOLUTION#7178, FIRST_DISP_TYPE#7192, FIRST_DISP_DIAG#7195, LAUNCH#7197, FUNCTIONALITY_CLASS#7199, WEIGHT#7201, TWO_SIM_IND#7209, RAM_CAPACITY#7236, ROM_CAPACITY#7237, MEMORY_CARD_IND#7238, BLUETOOTH_IND#7244, WLAN_IND#7246, GPS_IND#7248, GLONASS_IND#7249, A_GPS_IND#7250, GPRS_IND#7278, EDGE_IND#7280, LTE_IND#7307, IND_3G#7171, BRAND#7312]
# Arguments: HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [id=#902]
#
# (16) BroadcastHashJoin
# Left keys [1]: [TAC#7781]
# Right keys [1]: [TAC#7166]
# Join condition: None
#
# (17) Project
# Output [49]: [TAC#7781, CNT_USERS_OVERALL#7643L, CNT_ACTIVE_USERS#7645L, SUM_COUNT_DEVICE_CHANGES#7647L, AVG_COUNT_DEVICE_CHANGES#7649, AVG_ARPU_3M#7651, AVG_COUNT_PERIODS_POSIT_REV_12M#7653, AVG_ROAM_MIN#7655, AVG_CNT_CALL_OUT#7657, AVG_CNT_CALL_IN#7659, AVG_VOICE_OUT_DURATION#7661, AVG_VOICE_IN_DURATION#7663, AVG_UNIC_CTN_CPA#7665, AVG_CNT_SMS_OUT#7667, AVG_CNT_SMS_IN#7669, AVG_SMS_SHORT_NUM#7671, AVG_TOTAL_DATA_VOLUME#7673, AVG_MIN_BALANCE#7675, AVG_BALANCE#7677, AVG_MAX_BALANCE#7679, AVG_STD_BALANCE#7681, AVG_BLOCK_DAYS_COUNT#7683, PERC_USERS_OVERALL#7706, PERC_ACTIVE_USERS#7730, RATIO_ACTIVE_ALL#7755, DEVICE_TYPE#7478, OS#7169, TOUCHSCREEN_IND#7172, CAMERA_IND#7177, CAMERA_RESOLUTION#7178, FIRST_DISP_TYPE#7192, FIRST_DISP_DIAG#7195, LAUNCH#7197, FUNCTIONALITY_CLASS#7199, WEIGHT#7201, TWO_SIM_IND#7209, RAM_CAPACITY#7236, ROM_CAPACITY#7237, MEMORY_CARD_IND#7238, BLUETOOTH_IND#7244, WLAN_IND#7246, GPS_IND#7248, GLONASS_IND#7249, A_GPS_IND#7250, GPRS_IND#7278, EDGE_IND#7280, LTE_IND#7307, IND_3G#7171, BRAND#7312]
# Input [50]: [TAC#7781, CNT_USERS_OVERALL#7643L, CNT_ACTIVE_USERS#7645L, SUM_COUNT_DEVICE_CHANGES#7647L, AVG_COUNT_DEVICE_CHANGES#7649, AVG_ARPU_3M#7651, AVG_COUNT_PERIODS_POSIT_REV_12M#7653, AVG_ROAM_MIN#7655, AVG_CNT_CALL_OUT#7657, AVG_CNT_CALL_IN#7659, AVG_VOICE_OUT_DURATION#7661, AVG_VOICE_IN_DURATION#7663, AVG_UNIC_CTN_CPA#7665, AVG_CNT_SMS_OUT#7667, AVG_CNT_SMS_IN#7669, AVG_SMS_SHORT_NUM#7671, AVG_TOTAL_DATA_VOLUME#7673, AVG_MIN_BALANCE#7675, AVG_BALANCE#7677, AVG_MAX_BALANCE#7679, AVG_STD_BALANCE#7681, AVG_BLOCK_DAYS_COUNT#7683, PERC_USERS_OVERALL#7706, PERC_ACTIVE_USERS#7730, RATIO_ACTIVE_ALL#7755, DEVICE_TYPE#7478, TAC#7166, OS#7169, TOUCHSCREEN_IND#7172, CAMERA_IND#7177, CAMERA_RESOLUTION#7178, FIRST_DISP_TYPE#7192, FIRST_DISP_DIAG#7195, LAUNCH#7197, FUNCTIONALITY_CLASS#7199, WEIGHT#7201, TWO_SIM_IND#7209, RAM_CAPACITY#7236, ROM_CAPACITY#7237, MEMORY_CARD_IND#7238, BLUETOOTH_IND#7244, WLAN_IND#7246, GPS_IND#7248, GLONASS_IND#7249, A_GPS_IND#7250, GPRS_IND#7278, EDGE_IND#7280, LTE_IND#7307, IND_3G#7171, BRAND#7312]
#
# (18) BatchEvalPython
# Input [49]: [TAC#7781, CNT_USERS_OVERALL#7643L, CNT_ACTIVE_USERS#7645L, SUM_COUNT_DEVICE_CHANGES#7647L, AVG_COUNT_DEVICE_CHANGES#7649, AVG_ARPU_3M#7651, AVG_COUNT_PERIODS_POSIT_REV_12M#7653, AVG_ROAM_MIN#7655, AVG_CNT_CALL_OUT#7657, AVG_CNT_CALL_IN#7659, AVG_VOICE_OUT_DURATION#7661, AVG_VOICE_IN_DURATION#7663, AVG_UNIC_CTN_CPA#7665, AVG_CNT_SMS_OUT#7667, AVG_CNT_SMS_IN#7669, AVG_SMS_SHORT_NUM#7671, AVG_TOTAL_DATA_VOLUME#7673, AVG_MIN_BALANCE#7675, AVG_BALANCE#7677, AVG_MAX_BALANCE#7679, AVG_STD_BALANCE#7681, AVG_BLOCK_DAYS_COUNT#7683, PERC_USERS_OVERALL#7706, PERC_ACTIVE_USERS#7730, RATIO_ACTIVE_ALL#7755, DEVICE_TYPE#7478, OS#7169, TOUCHSCREEN_IND#7172, CAMERA_IND#7177, CAMERA_RESOLUTION#7178, FIRST_DISP_TYPE#7192, FIRST_DISP_DIAG#7195, LAUNCH#7197, FUNCTIONALITY_CLASS#7199, WEIGHT#7201, TWO_SIM_IND#7209, RAM_CAPACITY#7236, ROM_CAPACITY#7237, MEMORY_CARD_IND#7238, BLUETOOTH_IND#7244, WLAN_IND#7246, GPS_IND#7248, GLONASS_IND#7249, A_GPS_IND#7250, GPRS_IND#7278, EDGE_IND#7280, LTE_IND#7307, IND_3G#7171, BRAND#7312]
# Arguments: [norm_gb_mb(RAM_CAPACITY#7236)#8538, norm_gb_mb(ROM_CAPACITY#7237)#8591], [pythonUDF0#10669, pythonUDF1#10670]
#
# (19) Project
# Output [57]: [TAC#7781, CNT_USERS_OVERALL#7643L, CNT_ACTIVE_USERS#7645L, SUM_COUNT_DEVICE_CHANGES#7647L, AVG_COUNT_DEVICE_CHANGES#7649, AVG_ARPU_3M#7651, AVG_COUNT_PERIODS_POSIT_REV_12M#7653, AVG_ROAM_MIN#7655, AVG_CNT_CALL_OUT#7657, AVG_CNT_CALL_IN#7659, AVG_VOICE_OUT_DURATION#7661, AVG_VOICE_IN_DURATION#7663, AVG_UNIC_CTN_CPA#7665, AVG_CNT_SMS_OUT#7667, AVG_CNT_SMS_IN#7669, AVG_SMS_SHORT_NUM#7671, AVG_TOTAL_DATA_VOLUME#7673, AVG_MIN_BALANCE#7675, AVG_BALANCE#7677, AVG_MAX_BALANCE#7679, AVG_STD_BALANCE#7681, AVG_BLOCK_DAYS_COUNT#7683, PERC_USERS_OVERALL#7706, PERC_ACTIVE_USERS#7730, RATIO_ACTIVE_ALL#7755, CASE WHEN trim(DEVICE_TYPE#7478, None) IN (Feature_plus,Smartphone,Voice_centered,Tablets) THEN trim(DEVICE_TYPE#7478, None) ELSE Others END AS DEVICE_TYPE#7883, CASE WHEN trim(OS#7169, None) IN (BlackBerry OS,iOS,Android,Proprietary,Symbian) THEN trim(OS#7169, None) ELSE CASE WHEN trim(OS#7169, None) IN (Windows Phone,Windows Mobile,Windows) THEN Windows ELSE Others END END AS OS#7933, coalesce((TOUCHSCREEN_IND#7172 = Да), false) AS TOUCHSCREEN_IND#8132, coalesce((CAMERA_IND#7177 = Да), false) AS CAMERA_IND#8133, CASE WHEN (trim(CAMERA_RESOLUTION#7178, None) IN (-99,N/A,Нет данных) OR isnull(CAMERA_RESOLUTION#7178)) THEN 0.0 ELSE cast(regexp_replace(split(trim(CAMERA_RESOLUTION#7178, None),  , -1)[0], ,, ., 1) as float) END AS CAMERA_RESOLUTION#8183, CASE WHEN (trim(FIRST_DISP_TYPE#7192, None) IN (-99,N/A,Нет данных) OR isnull(FIRST_DISP_TYPE#7192)) THEN Nonname ELSE CASE WHEN trim(FIRST_DISP_TYPE#7192, None) IN (Super AMOLED,AMOLED,Dynamic AMOLED,Super AMOLED Plus,Optic AMOLED) THEN AMOLED ELSE CASE WHEN trim(FIRST_DISP_TYPE#7192, None) IN (TFT,PLS-TFT,TFT IPS (SFT),PLS) THEN TFT ELSE CASE WHEN trim(FIRST_DISP_TYPE#7192, None) IN (IPS,Super IPS+,True HD IPS Plus) THEN IPS ELSE CASE WHEN trim(FIRST_DISP_TYPE#7192, None) IN (LCD,UFB-LCD,Super LCD,Super LCD 5,Super LCD 6,3D LCD) THEN LCD ELSE CASE WHEN trim(FIRST_DISP_TYPE#7192, None) IN (CSTN,STN) THEN STN ELSE CASE WHEN trim(FIRST_DISP_TYPE#7192, None) IN (OLED,TN,LTPS) THEN trim(FIRST_DISP_TYPE#7192, None) ELSE Others END END END END END END END AS FIRST_DISP_TYPE#8233, CASE WHEN (trim(FIRST_DISP_DIAG#7195, None) IN (-99,N/A,Нет данных) OR isnull(FIRST_DISP_DIAG#7195)) THEN 0.0 ELSE cast(regexp_replace(split(trim(FIRST_DISP_DIAG#7195, None),  , -1)[0], ,, ., 1) as float) END AS FIRST_DISP_DIAG#8283, CASE WHEN (trim(FUNCTIONALITY_CLASS#7199, None) IN (-99,N/A) OR isnull(FUNCTIONALITY_CLASS#7199)) THEN Unknown ELSE trim(FUNCTIONALITY_CLASS#7199, None) END AS FUNCTIONALITY_CLASS#8384, CASE WHEN (trim(WEIGHT#7201, None) IN (-99,N/A,Нет данных) OR isnull(WEIGHT#7201)) THEN 0.0 ELSE cast(trim(WEIGHT#7201, None) as float) END AS WEIGHT#8435, CASE WHEN (trim(RAM_CAPACITY#7236, None) IN (-99,N/A,Нет данных) OR isnull(RAM_CAPACITY#7236)) THEN 0.0 ELSE pythonUDF0#10669 END AS RAM_CAPACITY#8539, CASE WHEN (trim(ROM_CAPACITY#7237, None) IN (-99,N/A,Нет данных) OR isnull(ROM_CAPACITY#7237)) THEN 0.0 ELSE pythonUDF1#10670 END AS ROM_CAPACITY#8592, ((trim(MEMORY_CARD_IND#7238, None) = Да) <=> true) AS MEMORY_CARD_IND#8644, ((trim(BLUETOOTH_IND#7244, None) = Да) <=> true) AS BLUETOOTH_IND#8696, ((trim(WLAN_IND#7246, None) = Да) <=> true) AS WLAN_IND#8748, ((trim(GPS_IND#7248, None) = Да) <=> true) AS GPS_IND#8800, ((trim(GLONASS_IND#7249, None) = Да) <=> true) AS GLONASS_IND#8852, ((trim(A_GPS_IND#7250, None) = Да) <=> true) AS A_GPS_IND#8904, ((trim(GPRS_IND#7278, None) = Да) <=> true) AS GPRS_IND#8956, ((trim(EDGE_IND#7280, None) = Да) <=> true) AS EDGE_IND#9008, ((trim(LTE_IND#7307, None) = Да) <=> true) AS LTE_IND#9060, ((trim(IND_3G#7171, None) = Да) <=> true) AS IND_3G#9112, BRAND#7312, CASE WHEN (length(LAUNCH#7197) = 10) THEN datediff(2018-11-01, cast(LAUNCH#7197 as date)) END AS LT_DEVICE#8333, (trim(TWO_SIM_IND#7209, None) IN (2 UICC,3 UICC,4 UICC,2 SIM-карты,Да,В зависимости от оконечного устройства) <=> true) AS MULTISIM_IND#8486, (BRAND#7312 = Nokia) AS IS_NOKIA#9164, (BRAND#7 ...
# Input [51]: [TAC#7781, CNT_USERS_OVERALL#7643L, CNT_ACTIVE_USERS#7645L, SUM_COUNT_DEVICE_CHANGES#7647L, AVG_COUNT_DEVICE_CHANGES#7649, AVG_ARPU_3M#7651, AVG_COUNT_PERIODS_POSIT_REV_12M#7653, AVG_ROAM_MIN#7655, AVG_CNT_CALL_OUT#7657, AVG_CNT_CALL_IN#7659, AVG_VOICE_OUT_DURATION#7661, AVG_VOICE_IN_DURATION#7663, AVG_UNIC_CTN_CPA#7665, AVG_CNT_SMS_OUT#7667, AVG_CNT_SMS_IN#7669, AVG_SMS_SHORT_NUM#7671, AVG_TOTAL_DATA_VOLUME#7673, AVG_MIN_BALANCE#7675, AVG_BALANCE#7677, AVG_MAX_BALANCE#7679, AVG_STD_BALANCE#7681, AVG_BLOCK_DAYS_COUNT#7683, PERC_USERS_OVERALL#7706, PERC_ACTIVE_USERS#7730, RATIO_ACTIVE_ALL#7755, DEVICE_TYPE#7478, OS#7169, TOUCHSCREEN_IND#7172, CAMERA_IND#7177, CAMERA_RESOLUTION#7178, FIRST_DISP_TYPE#7192, FIRST_DISP_DIAG#7195, LAUNCH#7197, FUNCTIONALITY_CLASS#7199, WEIGHT#7201, TWO_SIM_IND#7209, RAM_CAPACITY#7236, ROM_CAPACITY#7237, MEMORY_CARD_IND#7238, BLUETOOTH_IND#7244, WLAN_IND#7246, GPS_IND#7248, GLONASS_IND#7249, A_GPS_IND#7250, GPRS_IND#7278, EDGE_IND#7280, LTE_IND#7307, IND_3G#7171, BRAND#7312, pythonUDF0#10669, pythonUDF1#10670]
#
# (20) Scan parquet
# Output [3]: [TAC#9616, Price#9617, price_rub_to_kzt#9619]
# Batched: true
# Location: InMemoryFileIndex [file:/home/dulat/Desktop/nu-hackathon/data/datamart_avito_phones/MONTH_KEY=2019-12-01]
# PushedFilters: [IsNotNull(TAC)]
# ReadSchema: struct<TAC:int,Price:string,price_rub_to_kzt:string>
#
# (21) Filter
# Input [3]: [TAC#9616, Price#9617, price_rub_to_kzt#9619]
# Condition : isnotnull(TAC#9616)
#
# (22) Project
# Output [2]: [TAC#9616, CASE WHEN isnull(price_rub_to_kzt#9619) THEN price#9617 WHEN isnull(price#9617) THEN price_rub_to_kzt#9619 ELSE cast(((cast(price_rub_to_kzt#9619 as double) + cast(price#9617 as double)) / 2.0) as string) END AS avg_avito_price_1m#9640]
# Input [3]: [TAC#9616, Price#9617, price_rub_to_kzt#9619]
#
# (23) BroadcastExchange
# Input [2]: [TAC#9616, avg_avito_price_1m#9640]
# Arguments: HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [id=#908]
#
# (24) BroadcastHashJoin
# Left keys [1]: [TAC#7781]
# Right keys [1]: [TAC#9616]
# Join condition: None
#
# (25) Project
# Output [58]: [TAC#7781, CNT_USERS_OVERALL#7643L, CNT_ACTIVE_USERS#7645L, SUM_COUNT_DEVICE_CHANGES#7647L, AVG_COUNT_DEVICE_CHANGES#7649, AVG_ARPU_3M#7651, AVG_COUNT_PERIODS_POSIT_REV_12M#7653, AVG_ROAM_MIN#7655, AVG_CNT_CALL_OUT#7657, AVG_CNT_CALL_IN#7659, AVG_VOICE_OUT_DURATION#7661, AVG_VOICE_IN_DURATION#7663, AVG_UNIC_CTN_CPA#7665, AVG_CNT_SMS_OUT#7667, AVG_CNT_SMS_IN#7669, AVG_SMS_SHORT_NUM#7671, AVG_TOTAL_DATA_VOLUME#7673, AVG_MIN_BALANCE#7675, AVG_BALANCE#7677, AVG_MAX_BALANCE#7679, AVG_STD_BALANCE#7681, AVG_BLOCK_DAYS_COUNT#7683, PERC_USERS_OVERALL#7706, PERC_ACTIVE_USERS#7730, RATIO_ACTIVE_ALL#7755, DEVICE_TYPE#7883, OS#7933, TOUCHSCREEN_IND#8132, CAMERA_IND#8133, CAMERA_RESOLUTION#8183, FIRST_DISP_TYPE#8233, FIRST_DISP_DIAG#8283, FUNCTIONALITY_CLASS#8384, WEIGHT#8435, RAM_CAPACITY#8539, ROM_CAPACITY#8592, MEMORY_CARD_IND#8644, BLUETOOTH_IND#8696, WLAN_IND#8748, GPS_IND#8800, GLONASS_IND#8852, A_GPS_IND#8904, GPRS_IND#8956, EDGE_IND#9008, LTE_IND#9060, IND_3G#9112, BRAND#7312, LT_DEVICE#8333, MULTISIM_IND#8486, IS_NOKIA#9164, IS_SAMSUNG#9217, IS_APPLE#9271, IS_XIAOMI#9326, IS_HUAWEI#9382, IS_GOOGLE#9439, IS_MEIZU#9497, IS_EXPENSIVE#9556, avg_avito_price_1m#9640]
# Input [59]: [TAC#7781, CNT_USERS_OVERALL#7643L, CNT_ACTIVE_USERS#7645L, SUM_COUNT_DEVICE_CHANGES#7647L, AVG_COUNT_DEVICE_CHANGES#7649, AVG_ARPU_3M#7651, AVG_COUNT_PERIODS_POSIT_REV_12M#7653, AVG_ROAM_MIN#7655, AVG_CNT_CALL_OUT#7657, AVG_CNT_CALL_IN#7659, AVG_VOICE_OUT_DURATION#7661, AVG_VOICE_IN_DURATION#7663, AVG_UNIC_CTN_CPA#7665, AVG_CNT_SMS_OUT#7667, AVG_CNT_SMS_IN#7669, AVG_SMS_SHORT_NUM#7671, AVG_TOTAL_DATA_VOLUME#7673, AVG_MIN_BALANCE#7675, AVG_BALANCE#7677, AVG_MAX_BALANCE#7679, AVG_STD_BALANCE#7681, AVG_BLOCK_DAYS_COUNT#7683, PERC_USERS_OVERALL#7706, PERC_ACTIVE_USERS#7730, RATIO_ACTIVE_ALL#7755, DEVICE_TYPE#7883, OS#7933, TOUCHSCREEN_IND#8132, CAMERA_IND#8133, CAMERA_RESOLUTION#8183, FIRST_DISP_TYPE#8233, FIRST_DISP_DIAG#8283, FUNCTIONALITY_CLASS#8384, WEIGHT#8435, RAM_CAPACITY#8539, ROM_CAPACITY#8592, MEMORY_CARD_IND#8644, BLUETOOTH_IND#8696, WLAN_IND#8748, GPS_IND#8800, GLONASS_IND#8852, A_GPS_IND#8904, GPRS_IND#8956, EDGE_IND#9008, LTE_IND#9060, IND_3G#9112, BRAND#7312, LT_DEVICE#8333, MULTISIM_IND#8486, IS_NOKIA#9164, IS_SAMSUNG#9217, IS_APPLE#9271, IS_XIAOMI#9326, IS_HUAWEI#9382, IS_GOOGLE#9439, IS_MEIZU#9497, IS_EXPENSIVE#9556, TAC#9616, avg_avito_price_1m#9640]
#
# (26) Scan parquet
# Output [3]: [TAC#9624, Price#9625, price_rub_to_kzt#9627]
# Batched: true
# Location: InMemoryFileIndex [file:/home/dulat/Desktop/nu-hackathon/data/datamart_avito_phones/MONTH_KEY=2019-12-01]
# PushedFilters: [IsNotNull(TAC)]
# ReadSchema: struct<TAC:int,Price:string,price_rub_to_kzt:string>
#
# (27) Filter
# Input [3]: [TAC#9624, Price#9625, price_rub_to_kzt#9627]
# Condition : isnotnull(TAC#9624)
#
# (28) Project
# Output [2]: [TAC#9624, CASE WHEN isnull(price_rub_to_kzt#9627) THEN price#9625 WHEN isnull(price#9625) THEN price_rub_to_kzt#9627 ELSE cast(((cast(price_rub_to_kzt#9627 as double) + cast(price#9625 as double)) / 2.0) as string) END AS avg_avito_price_2m#9643]
# Input [3]: [TAC#9624, Price#9625, price_rub_to_kzt#9627]
#
# (29) BroadcastExchange
# Input [2]: [TAC#9624, avg_avito_price_2m#9643]
# Arguments: HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [id=#912]
#
# (30) BroadcastHashJoin
# Left keys [1]: [TAC#7781]
# Right keys [1]: [TAC#9624]
# Join condition: None
#
# (31) Project
# Output [59]: [TAC#7781, CNT_USERS_OVERALL#7643L, CNT_ACTIVE_USERS#7645L, SUM_COUNT_DEVICE_CHANGES#7647L, AVG_COUNT_DEVICE_CHANGES#7649, AVG_ARPU_3M#7651, AVG_COUNT_PERIODS_POSIT_REV_12M#7653, AVG_ROAM_MIN#7655, AVG_CNT_CALL_OUT#7657, AVG_CNT_CALL_IN#7659, AVG_VOICE_OUT_DURATION#7661, AVG_VOICE_IN_DURATION#7663, AVG_UNIC_CTN_CPA#7665, AVG_CNT_SMS_OUT#7667, AVG_CNT_SMS_IN#7669, AVG_SMS_SHORT_NUM#7671, AVG_TOTAL_DATA_VOLUME#7673, AVG_MIN_BALANCE#7675, AVG_BALANCE#7677, AVG_MAX_BALANCE#7679, AVG_STD_BALANCE#7681, AVG_BLOCK_DAYS_COUNT#7683, PERC_USERS_OVERALL#7706, PERC_ACTIVE_USERS#7730, RATIO_ACTIVE_ALL#7755, DEVICE_TYPE#7883, OS#7933, TOUCHSCREEN_IND#8132, CAMERA_IND#8133, CAMERA_RESOLUTION#8183, FIRST_DISP_TYPE#8233, FIRST_DISP_DIAG#8283, FUNCTIONALITY_CLASS#8384, WEIGHT#8435, RAM_CAPACITY#8539, ROM_CAPACITY#8592, MEMORY_CARD_IND#8644, BLUETOOTH_IND#8696, WLAN_IND#8748, GPS_IND#8800, GLONASS_IND#8852, A_GPS_IND#8904, GPRS_IND#8956, EDGE_IND#9008, LTE_IND#9060, IND_3G#9112, BRAND#7312, LT_DEVICE#8333, MULTISIM_IND#8486, IS_NOKIA#9164, IS_SAMSUNG#9217, IS_APPLE#9271, IS_XIAOMI#9326, IS_HUAWEI#9382, IS_GOOGLE#9439, IS_MEIZU#9497, IS_EXPENSIVE#9556, avg_avito_price_1m#9640, avg_avito_price_2m#9643]
# Input [60]: [TAC#7781, CNT_USERS_OVERALL#7643L, CNT_ACTIVE_USERS#7645L, SUM_COUNT_DEVICE_CHANGES#7647L, AVG_COUNT_DEVICE_CHANGES#7649, AVG_ARPU_3M#7651, AVG_COUNT_PERIODS_POSIT_REV_12M#7653, AVG_ROAM_MIN#7655, AVG_CNT_CALL_OUT#7657, AVG_CNT_CALL_IN#7659, AVG_VOICE_OUT_DURATION#7661, AVG_VOICE_IN_DURATION#7663, AVG_UNIC_CTN_CPA#7665, AVG_CNT_SMS_OUT#7667, AVG_CNT_SMS_IN#7669, AVG_SMS_SHORT_NUM#7671, AVG_TOTAL_DATA_VOLUME#7673, AVG_MIN_BALANCE#7675, AVG_BALANCE#7677, AVG_MAX_BALANCE#7679, AVG_STD_BALANCE#7681, AVG_BLOCK_DAYS_COUNT#7683, PERC_USERS_OVERALL#7706, PERC_ACTIVE_USERS#7730, RATIO_ACTIVE_ALL#7755, DEVICE_TYPE#7883, OS#7933, TOUCHSCREEN_IND#8132, CAMERA_IND#8133, CAMERA_RESOLUTION#8183, FIRST_DISP_TYPE#8233, FIRST_DISP_DIAG#8283, FUNCTIONALITY_CLASS#8384, WEIGHT#8435, RAM_CAPACITY#8539, ROM_CAPACITY#8592, MEMORY_CARD_IND#8644, BLUETOOTH_IND#8696, WLAN_IND#8748, GPS_IND#8800, GLONASS_IND#8852, A_GPS_IND#8904, GPRS_IND#8956, EDGE_IND#9008, LTE_IND#9060, IND_3G#9112, BRAND#7312, LT_DEVICE#8333, MULTISIM_IND#8486, IS_NOKIA#9164, IS_SAMSUNG#9217, IS_APPLE#9271, IS_XIAOMI#9326, IS_HUAWEI#9382, IS_GOOGLE#9439, IS_MEIZU#9497, IS_EXPENSIVE#9556, avg_avito_price_1m#9640, TAC#9624, avg_avito_price_2m#9643]
#
# (32) Scan parquet
# Output [3]: [TAC#9632, Price#9633, price_rub_to_kzt#9635]
# Batched: true
# Location: InMemoryFileIndex [file:/home/dulat/Desktop/nu-hackathon/data/datamart_avito_phones/MONTH_KEY=2019-12-01]
# PushedFilters: [IsNotNull(TAC)]
# ReadSchema: struct<TAC:int,Price:string,price_rub_to_kzt:string>
#
# (33) Filter
# Input [3]: [TAC#9632, Price#9633, price_rub_to_kzt#9635]
# Condition : isnotnull(TAC#9632)
#
# (34) Project
# Output [2]: [TAC#9632, CASE WHEN isnull(price_rub_to_kzt#9635) THEN price#9633 WHEN isnull(price#9633) THEN price_rub_to_kzt#9635 ELSE cast(((cast(price_rub_to_kzt#9635 as double) + cast(price#9633 as double)) / 2.0) as string) END AS avg_avito_price_3m#9646]
# Input [3]: [TAC#9632, Price#9633, price_rub_to_kzt#9635]
#
# (35) BroadcastExchange
# Input [2]: [TAC#9632, avg_avito_price_3m#9646]
# Arguments: HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [id=#916]
#
# (36) BroadcastHashJoin
# Left keys [1]: [TAC#7781]
# Right keys [1]: [TAC#9632]
# Join condition: None
#
# (37) Project
# Output [61]: [TAC#7781, CNT_USERS_OVERALL#7643L, CNT_ACTIVE_USERS#7645L, SUM_COUNT_DEVICE_CHANGES#7647L, AVG_COUNT_DEVICE_CHANGES#7649, AVG_ARPU_3M#7651, AVG_COUNT_PERIODS_POSIT_REV_12M#7653, AVG_ROAM_MIN#7655, AVG_CNT_CALL_OUT#7657, AVG_CNT_CALL_IN#7659, AVG_VOICE_OUT_DURATION#7661, AVG_VOICE_IN_DURATION#7663, AVG_UNIC_CTN_CPA#7665, AVG_CNT_SMS_OUT#7667, AVG_CNT_SMS_IN#7669, AVG_SMS_SHORT_NUM#7671, AVG_TOTAL_DATA_VOLUME#7673, AVG_MIN_BALANCE#7675, AVG_BALANCE#7677, AVG_MAX_BALANCE#7679, AVG_STD_BALANCE#7681, AVG_BLOCK_DAYS_COUNT#7683, PERC_USERS_OVERALL#7706, PERC_ACTIVE_USERS#7730, RATIO_ACTIVE_ALL#7755, DEVICE_TYPE#7883, OS#7933, TOUCHSCREEN_IND#8132, CAMERA_IND#8133, CAMERA_RESOLUTION#8183, FIRST_DISP_TYPE#8233, FIRST_DISP_DIAG#8283, FUNCTIONALITY_CLASS#8384, WEIGHT#8435, RAM_CAPACITY#8539, ROM_CAPACITY#8592, MEMORY_CARD_IND#8644, BLUETOOTH_IND#8696, WLAN_IND#8748, GPS_IND#8800, GLONASS_IND#8852, A_GPS_IND#8904, GPRS_IND#8956, EDGE_IND#9008, LTE_IND#9060, IND_3G#9112, BRAND#7312, LT_DEVICE#8333, MULTISIM_IND#8486, IS_NOKIA#9164, IS_SAMSUNG#9217, IS_APPLE#9271, IS_XIAOMI#9326, IS_HUAWEI#9382, IS_GOOGLE#9439, IS_MEIZU#9497, IS_EXPENSIVE#9556, avg_avito_price_1m#9640, avg_avito_price_2m#9643, avg_avito_price_3m#9646, (((cast(isnotnull(avg_avito_price_1m#9640) as int) + 0) + cast(isnotnull(avg_avito_price_2m#9643) as int)) + cast(isnotnull(avg_avito_price_3m#9646) as int)) AS NOT_NULL_PRICE_AMT_AVITO#9832]
# Input [61]: [TAC#7781, CNT_USERS_OVERALL#7643L, CNT_ACTIVE_USERS#7645L, SUM_COUNT_DEVICE_CHANGES#7647L, AVG_COUNT_DEVICE_CHANGES#7649, AVG_ARPU_3M#7651, AVG_COUNT_PERIODS_POSIT_REV_12M#7653, AVG_ROAM_MIN#7655, AVG_CNT_CALL_OUT#7657, AVG_CNT_CALL_IN#7659, AVG_VOICE_OUT_DURATION#7661, AVG_VOICE_IN_DURATION#7663, AVG_UNIC_CTN_CPA#7665, AVG_CNT_SMS_OUT#7667, AVG_CNT_SMS_IN#7669, AVG_SMS_SHORT_NUM#7671, AVG_TOTAL_DATA_VOLUME#7673, AVG_MIN_BALANCE#7675, AVG_BALANCE#7677, AVG_MAX_BALANCE#7679, AVG_STD_BALANCE#7681, AVG_BLOCK_DAYS_COUNT#7683, PERC_USERS_OVERALL#7706, PERC_ACTIVE_USERS#7730, RATIO_ACTIVE_ALL#7755, DEVICE_TYPE#7883, OS#7933, TOUCHSCREEN_IND#8132, CAMERA_IND#8133, CAMERA_RESOLUTION#8183, FIRST_DISP_TYPE#8233, FIRST_DISP_DIAG#8283, FUNCTIONALITY_CLASS#8384, WEIGHT#8435, RAM_CAPACITY#8539, ROM_CAPACITY#8592, MEMORY_CARD_IND#8644, BLUETOOTH_IND#8696, WLAN_IND#8748, GPS_IND#8800, GLONASS_IND#8852, A_GPS_IND#8904, GPRS_IND#8956, EDGE_IND#9008, LTE_IND#9060, IND_3G#9112, BRAND#7312, LT_DEVICE#8333, MULTISIM_IND#8486, IS_NOKIA#9164, IS_SAMSUNG#9217, IS_APPLE#9271, IS_XIAOMI#9326, IS_HUAWEI#9382, IS_GOOGLE#9439, IS_MEIZU#9497, IS_EXPENSIVE#9556, avg_avito_price_1m#9640, avg_avito_price_2m#9643, TAC#9632, avg_avito_price_3m#9646]
#
# (38) Project
# Output [62]: [TAC#7781, CNT_USERS_OVERALL#7643L, CNT_ACTIVE_USERS#7645L, SUM_COUNT_DEVICE_CHANGES#7647L, AVG_COUNT_DEVICE_CHANGES#7649, AVG_ARPU_3M#7651, AVG_COUNT_PERIODS_POSIT_REV_12M#7653, AVG_ROAM_MIN#7655, AVG_CNT_CALL_OUT#7657, AVG_CNT_CALL_IN#7659, AVG_VOICE_OUT_DURATION#7661, AVG_VOICE_IN_DURATION#7663, AVG_UNIC_CTN_CPA#7665, AVG_CNT_SMS_OUT#7667, AVG_CNT_SMS_IN#7669, AVG_SMS_SHORT_NUM#7671, AVG_TOTAL_DATA_VOLUME#7673, AVG_MIN_BALANCE#7675, AVG_BALANCE#7677, AVG_MAX_BALANCE#7679, AVG_STD_BALANCE#7681, AVG_BLOCK_DAYS_COUNT#7683, PERC_USERS_OVERALL#7706, PERC_ACTIVE_USERS#7730, RATIO_ACTIVE_ALL#7755, DEVICE_TYPE#7883, OS#7933, TOUCHSCREEN_IND#8132, CAMERA_IND#8133, CAMERA_RESOLUTION#8183, FIRST_DISP_TYPE#8233, FIRST_DISP_DIAG#8283, FUNCTIONALITY_CLASS#8384, WEIGHT#8435, RAM_CAPACITY#8539, ROM_CAPACITY#8592, MEMORY_CARD_IND#8644, BLUETOOTH_IND#8696, WLAN_IND#8748, GPS_IND#8800, GLONASS_IND#8852, A_GPS_IND#8904, GPRS_IND#8956, EDGE_IND#9008, LTE_IND#9060, IND_3G#9112, BRAND#7312, LT_DEVICE#8333, MULTISIM_IND#8486, IS_NOKIA#9164, IS_SAMSUNG#9217, IS_APPLE#9271, IS_XIAOMI#9326, IS_HUAWEI#9382, IS_GOOGLE#9439, IS_MEIZU#9497, IS_EXPENSIVE#9556, avg_avito_price_1m#9640, avg_avito_price_2m#9643, avg_avito_price_3m#9646, NOT_NULL_PRICE_AMT_AVITO#9832, ((((cast(avg_avito_price_1m#9640 as double) + 0.0) + cast(avg_avito_price_1m#9640 as double)) + cast(avg_avito_price_1m#9640 as double)) / cast(NOT_NULL_PRICE_AMT_AVITO#9832 as double)) AS AVG_PRICE_3M_AVITO#9896]
# Input [61]: [TAC#7781, CNT_USERS_OVERALL#7643L, CNT_ACTIVE_USERS#7645L, SUM_COUNT_DEVICE_CHANGES#7647L, AVG_COUNT_DEVICE_CHANGES#7649, AVG_ARPU_3M#7651, AVG_COUNT_PERIODS_POSIT_REV_12M#7653, AVG_ROAM_MIN#7655, AVG_CNT_CALL_OUT#7657, AVG_CNT_CALL_IN#7659, AVG_VOICE_OUT_DURATION#7661, AVG_VOICE_IN_DURATION#7663, AVG_UNIC_CTN_CPA#7665, AVG_CNT_SMS_OUT#7667, AVG_CNT_SMS_IN#7669, AVG_SMS_SHORT_NUM#7671, AVG_TOTAL_DATA_VOLUME#7673, AVG_MIN_BALANCE#7675, AVG_BALANCE#7677, AVG_MAX_BALANCE#7679, AVG_STD_BALANCE#7681, AVG_BLOCK_DAYS_COUNT#7683, PERC_USERS_OVERALL#7706, PERC_ACTIVE_USERS#7730, RATIO_ACTIVE_ALL#7755, DEVICE_TYPE#7883, OS#7933, TOUCHSCREEN_IND#8132, CAMERA_IND#8133, CAMERA_RESOLUTION#8183, FIRST_DISP_TYPE#8233, FIRST_DISP_DIAG#8283, FUNCTIONALITY_CLASS#8384, WEIGHT#8435, RAM_CAPACITY#8539, ROM_CAPACITY#8592, MEMORY_CARD_IND#8644, BLUETOOTH_IND#8696, WLAN_IND#8748, GPS_IND#8800, GLONASS_IND#8852, A_GPS_IND#8904, GPRS_IND#8956, EDGE_IND#9008, LTE_IND#9060, IND_3G#9112, BRAND#7312, LT_DEVICE#8333, MULTISIM_IND#8486, IS_NOKIA#9164, IS_SAMSUNG#9217, IS_APPLE#9271, IS_XIAOMI#9326, IS_HUAWEI#9382, IS_GOOGLE#9439, IS_MEIZU#9497, IS_EXPENSIVE#9556, avg_avito_price_1m#9640, avg_avito_price_2m#9643, avg_avito_price_3m#9646, NOT_NULL_PRICE_AMT_AVITO#9832]
#
# (39) Scan csv
# Output [2]: [PRIORITY_TAC#9978, PRICE#9980]
# Batched: false
# Location: InMemoryFileIndex [file:/home/dulat/Desktop/nu-hackathon/data/vendor_telprice.csv]
# PushedFilters: [IsNotNull(PRIORITY_TAC)]
# ReadSchema: struct<PRIORITY_TAC:string,PRICE:string>
#
# (40) Filter
# Input [2]: [PRIORITY_TAC#9978, PRICE#9980]
# Condition : isnotnull(PRIORITY_TAC#9978)
#
# (41) Project
# Output [2]: [PRIORITY_TAC#9978 AS TAC#9984, cast(PRICE#9980 as float) AS PRICE_VENDOR_OLD#9986]
# Input [2]: [PRIORITY_TAC#9978, PRICE#9980]
#
# (42) BroadcastExchange
# Input [2]: [TAC#9984, PRICE_VENDOR_OLD#9986]
# Arguments: HashedRelationBroadcastMode(List(cast(cast(input[0, string, true] as int) as bigint)),false), [id=#921]
#
# (43) BroadcastHashJoin
# Left keys [1]: [TAC#7781]
# Right keys [1]: [cast(TAC#9984 as int)]
# Join condition: None
#
# (44) Project
# Output [67]: [TAC#7781, CNT_USERS_OVERALL#7643L, CNT_ACTIVE_USERS#7645L, SUM_COUNT_DEVICE_CHANGES#7647L, AVG_COUNT_DEVICE_CHANGES#7649, AVG_ARPU_3M#7651, AVG_COUNT_PERIODS_POSIT_REV_12M#7653, AVG_ROAM_MIN#7655, AVG_CNT_CALL_OUT#7657, AVG_CNT_CALL_IN#7659, AVG_VOICE_OUT_DURATION#7661, AVG_VOICE_IN_DURATION#7663, AVG_UNIC_CTN_CPA#7665, AVG_CNT_SMS_OUT#7667, AVG_CNT_SMS_IN#7669, AVG_SMS_SHORT_NUM#7671, AVG_TOTAL_DATA_VOLUME#7673, AVG_MIN_BALANCE#7675, AVG_BALANCE#7677, AVG_MAX_BALANCE#7679, AVG_STD_BALANCE#7681, AVG_BLOCK_DAYS_COUNT#7683, PERC_USERS_OVERALL#7706, PERC_ACTIVE_USERS#7730, RATIO_ACTIVE_ALL#7755, DEVICE_TYPE#7883, OS#7933, TOUCHSCREEN_IND#8132, CAMERA_IND#8133, CAMERA_RESOLUTION#8183, FIRST_DISP_TYPE#8233, FIRST_DISP_DIAG#8283, FUNCTIONALITY_CLASS#8384, WEIGHT#8435, RAM_CAPACITY#8539, ROM_CAPACITY#8592, MEMORY_CARD_IND#8644, BLUETOOTH_IND#8696, WLAN_IND#8748, GPS_IND#8800, GLONASS_IND#8852, A_GPS_IND#8904, GPRS_IND#8956, EDGE_IND#9008, LTE_IND#9060, IND_3G#9112, BRAND#7312, LT_DEVICE#8333, MULTISIM_IND#8486, IS_NOKIA#9164, IS_SAMSUNG#9217, IS_APPLE#9271, IS_XIAOMI#9326, IS_HUAWEI#9382, IS_GOOGLE#9439, IS_MEIZU#9497, IS_EXPENSIVE#9556, cast(avg_avito_price_1m#9640 as float) AS avg_avito_price_1m#10259, cast(avg_avito_price_2m#9643 as float) AS avg_avito_price_2m#10328, cast(avg_avito_price_3m#9646 as float) AS avg_avito_price_3m#10397, NOT_NULL_PRICE_AMT_AVITO#9832, AVG_PRICE_3M_AVITO#9896, PRICE_VENDOR_OLD#9986, cast(CASE WHEN (isnotnull(avg_avito_price_1m#9640) AND isnotnull(PRICE_VENDOR_OLD#9986)) THEN cast(((cast(avg_avito_price_1m#9640 as double) + cast(PRICE_VENDOR_OLD#9986 as double)) / 2.0) as string) ELSE CASE WHEN isnotnull(avg_avito_price_1m#9640) THEN avg_avito_price_1m#9640 ELSE cast(PRICE_VENDOR_OLD#9986 as string) END END as float) AS AVG_PRICE#10055, cast(CASE WHEN (isnotnull(AVG_PRICE_3M_AVITO#9896) AND isnotnull(PRICE_VENDOR_OLD#9986)) THEN ((AVG_PRICE_3M_AVITO#9896 + cast(PRICE_VENDOR_OLD#9986 as double)) / 2.0) ELSE CASE WHEN isnotnull(AVG_PRICE_3M_AVITO#9896) THEN AVG_PRICE_3M_AVITO#9896 ELSE cast(PRICE_VENDOR_OLD#9986 as double) END END as float) AS AVG_PRICE_3M#10122, cast(CASE WHEN isnotnull(avg_avito_price_1m#9640) THEN avg_avito_price_1m#9640 ELSE cast(PRICE_VENDOR_OLD#9986 as string) END as float) AS TARGET_PRICE#10466, 2018-11-01 AS MONTH_KEY#10601]
# Input [64]: [TAC#7781, CNT_USERS_OVERALL#7643L, CNT_ACTIVE_USERS#7645L, SUM_COUNT_DEVICE_CHANGES#7647L, AVG_COUNT_DEVICE_CHANGES#7649, AVG_ARPU_3M#7651, AVG_COUNT_PERIODS_POSIT_REV_12M#7653, AVG_ROAM_MIN#7655, AVG_CNT_CALL_OUT#7657, AVG_CNT_CALL_IN#7659, AVG_VOICE_OUT_DURATION#7661, AVG_VOICE_IN_DURATION#7663, AVG_UNIC_CTN_CPA#7665, AVG_CNT_SMS_OUT#7667, AVG_CNT_SMS_IN#7669, AVG_SMS_SHORT_NUM#7671, AVG_TOTAL_DATA_VOLUME#7673, AVG_MIN_BALANCE#7675, AVG_BALANCE#7677, AVG_MAX_BALANCE#7679, AVG_STD_BALANCE#7681, AVG_BLOCK_DAYS_COUNT#7683, PERC_USERS_OVERALL#7706, PERC_ACTIVE_USERS#7730, RATIO_ACTIVE_ALL#7755, DEVICE_TYPE#7883, OS#7933, TOUCHSCREEN_IND#8132, CAMERA_IND#8133, CAMERA_RESOLUTION#8183, FIRST_DISP_TYPE#8233, FIRST_DISP_DIAG#8283, FUNCTIONALITY_CLASS#8384, WEIGHT#8435, RAM_CAPACITY#8539, ROM_CAPACITY#8592, MEMORY_CARD_IND#8644, BLUETOOTH_IND#8696, WLAN_IND#8748, GPS_IND#8800, GLONASS_IND#8852, A_GPS_IND#8904, GPRS_IND#8956, EDGE_IND#9008, LTE_IND#9060, IND_3G#9112, BRAND#7312, LT_DEVICE#8333, MULTISIM_IND#8486, IS_NOKIA#9164, IS_SAMSUNG#9217, IS_APPLE#9271, IS_XIAOMI#9326, IS_HUAWEI#9382, IS_GOOGLE#9439, IS_MEIZU#9497, IS_EXPENSIVE#9556, avg_avito_price_1m#9640, avg_avito_price_2m#9643, avg_avito_price_3m#9646, NOT_NULL_PRICE_AMT_AVITO#9832, AVG_PRICE_3M_AVITO#9896, TAC#9984, PRICE_VENDOR_OLD#9986]
#
# (45) AdaptiveSparkPlan
# Output [67]: [TAC#7781, CNT_USERS_OVERALL#7643L, CNT_ACTIVE_USERS#7645L, SUM_COUNT_DEVICE_CHANGES#7647L, AVG_COUNT_DEVICE_CHANGES#7649, AVG_ARPU_3M#7651, AVG_COUNT_PERIODS_POSIT_REV_12M#7653, AVG_ROAM_MIN#7655, AVG_CNT_CALL_OUT#7657, AVG_CNT_CALL_IN#7659, AVG_VOICE_OUT_DURATION#7661, AVG_VOICE_IN_DURATION#7663, AVG_UNIC_CTN_CPA#7665, AVG_CNT_SMS_OUT#7667, AVG_CNT_SMS_IN#7669, AVG_SMS_SHORT_NUM#7671, AVG_TOTAL_DATA_VOLUME#7673, AVG_MIN_BALANCE#7675, AVG_BALANCE#7677, AVG_MAX_BALANCE#7679, AVG_STD_BALANCE#7681, AVG_BLOCK_DAYS_COUNT#7683, PERC_USERS_OVERALL#7706, PERC_ACTIVE_USERS#7730, RATIO_ACTIVE_ALL#7755, DEVICE_TYPE#7883, OS#7933, TOUCHSCREEN_IND#8132, CAMERA_IND#8133, CAMERA_RESOLUTION#8183, FIRST_DISP_TYPE#8233, FIRST_DISP_DIAG#8283, FUNCTIONALITY_CLASS#8384, WEIGHT#8435, RAM_CAPACITY#8539, ROM_CAPACITY#8592, MEMORY_CARD_IND#8644, BLUETOOTH_IND#8696, WLAN_IND#8748, GPS_IND#8800, GLONASS_IND#8852, A_GPS_IND#8904, GPRS_IND#8956, EDGE_IND#9008, LTE_IND#9060, IND_3G#9112, BRAND#7312, LT_DEVICE#8333, MULTISIM_IND#8486, IS_NOKIA#9164, IS_SAMSUNG#9217, IS_APPLE#9271, IS_XIAOMI#9326, IS_HUAWEI#9382, IS_GOOGLE#9439, IS_MEIZU#9497, IS_EXPENSIVE#9556, avg_avito_price_1m#10259, avg_avito_price_2m#10328, avg_avito_price_3m#10397, NOT_NULL_PRICE_AMT_AVITO#9832, AVG_PRICE_3M_AVITO#9896, PRICE_VENDOR_OLD#9986, AVG_PRICE#10055, AVG_PRICE_3M#10122, TARGET_PRICE#10466, MONTH_KEY#10601]
# Arguments: isFinalPlan=false
